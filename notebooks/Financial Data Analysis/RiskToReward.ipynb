# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  45.9000      NaN
# 2014-10-02  45.7600  -0.0031
# 2014-10-03  46.0900   0.0072
# 2014-10-06  46.0900   0.0000
# 2014-10-07  45.5300  -0.0122
# ...             ...      ...
# 2022-12-23 238.7300   0.0023
# 2022-12-27 236.9600  -0.0074
# 2022-12-28 234.5300  -0.0103
# 2022-12-29 241.0100   0.0276
# 2022-12-30 239.8200  -0.0049
#
# [2078 rows x 2 columns]

# %%
msft.Price.plot(figsize = (15, 8), fontsize = 13) #create a plot of the price 
plt.legend(fontsize = 13)
plt.show()

# %%
msft.describe()
# Out:
#           Price   Returns
# count 2078.0000 2077.0000
# mean   139.9692    0.0010
# std     88.8490    0.0176
# min     40.2900   -0.1474
# 25%     58.4000   -0.0070
# 50%    108.0050    0.0007
# 75%    217.6400    0.0098
# max    343.1100    0.1422

# %%
mu = msft.Returns.mean() # arithmetic mean return -> Reward
mu
# Out:
# 0.0009517218880589636

# %%
sigma = msft.Returns.std() # standard deviation of returns -> Risk/Volatility
sigma
# Out:
# 0.017633989436112347

# %%
np.sqrt(msft.Returns.var())
# Out:
# 0.017633989436112347
