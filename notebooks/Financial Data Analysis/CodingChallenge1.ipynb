# %%
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

# %%
start = "2015-01-01" #set start date for data we will pull
end = "2020-12-31"    #set end   date for data we will pull

# %%
symbol = "GE, BA"

# %%
df = yf.download(symbol, start, end) #pull data from yahoo finance and place it into a dataframe
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df
# Out:
#              Adj Close                   Close                    High  \
#                     BA          GE          BA          GE          BA
# Date
# 2015-01-02  113.657204  167.184036  129.949997  192.769226  131.839996
# 2015-01-05  112.870056  164.115265  129.050003  189.230774  129.919998
# 2015-01-06  111.540619  160.579391  127.529999  185.153839  129.619995
# 2015-01-07  113.272362  160.646103  129.509995  185.230774  129.970001
# 2015-01-08  115.275261  162.580811  131.800003  187.461533  131.990005
# ...                ...         ...         ...         ...         ...
# 2020-12-23  219.690002   86.235374  219.690002   86.879997  224.399994
# 2020-12-24  217.149994   84.567833  217.149994   85.199997  219.880005
# 2020-12-28  216.089996   84.488441  216.089996   85.120003  219.199997
# 2020-12-29  216.250000   83.853188  216.250000   84.480003  221.679993
# 2020-12-30  216.669998   85.044281  216.669998   85.680000  218.550003
#
# ...

# %%
norm = df.Close.div(df.Close.iloc[0]) #normalizing close prices for all
norm.dropna().plot(figsize = (15,8), fontsize = 13) #create a plot of all the normalized close prices
plt.legend(fontsize = 13)
plt.show()

# %%
norm.GE.dropna().plot(figsize = (15,8), fontsize = 13) #create a plot of GE normalized close prices
plt.legend(fontsize = 13)
plt.show()
